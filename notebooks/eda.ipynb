# %%
from lib.config import Directories
import polars as pl


data = pl.read_csv(Directories.EXTERNAL_DATA_DIR.value / "flood-control-projects-visual_2025-11-08.csv", infer_schema_length=10000)

# %%
data
# Out:
# shape: (9_855, 36)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ GlobalID  ┆ InfraYear ┆ Region    ┆ Province  ┆ … ┆ StartDate ┆ type      ┆ slug      ┆ _geo     │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │ str       ┆ i64       ┆ str       ┆ str       ┆   ┆ str       ┆ str       ┆ str       ┆ str      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 79e8be69- ┆ 2024      ┆ Region    ┆ PALAWAN   ┆ … ┆ 02/15/202 ┆ flood_con ┆ construct ┆ [object  │
# │ 90ab-488d ┆           ┆ IV-B      ┆           ┆   ┆ 4         ┆ trol      ┆ ion-of-ba ┆ Object]  │
# │ -bf10-920 ┆           ┆           ┆           ┆   ┆           ┆           ┆ buyan-riv ┆          │
# │ 4d4…      ┆           ┆           ┆           ┆   ┆           ┆           ┆ er-…      ┆          │
# ...

# %%
data["InfraYear"].describe()
# Out:
# shape: (9, 2)
# ┌────────────┬─────────────┐
# │ statistic  ┆ value       │
# │ ---        ┆ ---         │
# │ str        ┆ f64         │
# ╞════════════╪═════════════╡
# │ count      ┆ 9855.0      │
# │ null_count ┆ 0.0         │
# │ mean       ┆ 2022.766109 │
# │ std        ┆ 0.918645    │
# │ min        ┆ 2018.0      │
# │ 25%        ┆ 2022.0      │
# │ 50%        ┆ 2023.0      │
# │ 75%        ┆ 2023.0      │
# │ max        ┆ 2025.0      │
# └────────────┴─────────────┘

# %%
data.describe(
    
)
# Out:
# shape: (9, 37)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ statistic ┆ GlobalID  ┆ InfraYear ┆ Region    ┆ … ┆ StartDate ┆ type      ┆ slug      ┆ _geo     │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │ str       ┆ str       ┆ f64       ┆ str       ┆   ┆ str       ┆ str       ┆ str       ┆ str      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ count     ┆ 9855      ┆ 9855.0    ┆ 9855      ┆ … ┆ 9855      ┆ 9855      ┆ 9855      ┆ 9855     │
# │ null_coun ┆ 0         ┆ 0.0       ┆ 0         ┆ … ┆ 0         ┆ 0         ┆ 0         ┆ 0        │
# │ t         ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ mean      ┆ null      ┆ 2022.7661 ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# ...
